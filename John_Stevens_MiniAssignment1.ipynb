# %% [markdown]
# <a href="https://colab.research.google.com/github/JT-Creates/Arduino/blob/main/John_Stevens_MiniAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from urllib.request import Request, urlopen
# Returns the area of a rectangle 
def area(length : float, width : float):
  return length * width

# Fix missing variables
def load_dependancies(id : str):
  if id == "my_list":
    # In case the third code block was not run, this will 
    try:
      return my_list
    except Exception:
      print("list is not laoded!")
    return ["Hamaltonien cycle", "Chudnovsky formula", "Pythagorean formula", "Rockwell Automation's Turbo-Encabulator", "Electronic Numarical Integrator and Computer", "Conway's Game of Life", "Bonsai", "Peregrine Falcon"]
  if id == "dictionary_1":
    try:
      return dictionary_1
    except Exception:
      print("dictionary is not loaded")
    return {'California': 38332521,
            'Texas': 26448193,
            'New York': 19651127,
            'Florida': 19552860,
            'Illinois': 12882135, }
my_list = load_dependancies("my_list")
dictionary_1 = load_dependancies("dictionary_1")
# This function prints all items up to the index entered.
def upTo():
  max_index = eval(input("Enter a number between 1 and 8:\n")) - 1
  if (max_index < 8):
    for i in range(max_index):
      print(my_list[i])
   
# This function takes an integer checks if it is within the length of the array and less then 8.
def validate_Index(ui_index : int):
  try:
    if ui_index in range(len(my_list)) and ui_index < 8:
        return True
    else:
      print("Number is less than 0 or greater than", (len(my_list)) + "!")
      return False
  except IndexError:
    print("Index out of bounds.")
    return False

# Feedback system
def feedback(code_id):
  yesno = False
  if input("Provide feedback. [y]es / [n]o:\t") == "y":
    yesno = True
  while yesno:
    username = "Anonymous"
    lines = ""
    comment_id = 1
    comments = ""
    try:
      name = input("Name:\t")
      if len(name.strip(" ")) != 0:
        username = name
      rating = eval(input("rating between 1 and 10:\t")) - 1
      if rating in range(10):
        rating += 1
        url = "http://codingcommons.tech/programs/EU/DTSC_220/feedback/index.php"
        while input("Add more feedback. [y]es / [n]o:\t") == "y":
          try:
            lines = input("Please Enter comment #" + (str)(comment_id) + ":\t")
            comments += ((str)(comment_id) + lines)
            comment_id += 1
          except Exception:
            print("Failed")
            continue
        req = Request(url + "?name=" + username + "&code_block=" + code_id + "&rating=" + (str)(rating) + "&comments=" + comments, headers={'User-Agent': 'Mozilla/5.0', 'Content-type':'text/plain'})
        resp = urlopen(req).read()
        if len(resp) > 8:
          print(resp)
          return
    except Exception as x:
      print(x)
      valid = False
      print("Something whent wrong.")
  return 
class xm:
  def gm():
    return False
  def em():
    return True
print(xm.em())

# Mini Assignment 1
class mini_assignment_1:
  def code_block_1():
    l = eval(input("Enter a length: "))
    w = eval(input("Enter a width: "))
    a = area(l, w)
    print("The area of the rectangle is", a, "units².")
    feedback("Mini_Assignment_1_Block_1")
    return True
  def code_block_2():
    print("\u001B[4mThis is an example of envoking the area function.\u001B[0m", "\nRectangle with a length of\033[47m 4 \033[0minches and width of\033[47m 8 \033[0minches is\033[47m", area(4,8), "\033[0minches². \u0020[07;22;45m\u0020")
    feedback("Mini_Assignment_1_Block_2")
    return True
  def code_block_3():
    my_list = ["Hamaltonien cycle", "Chudnovsky formula", "Pythagorean formula", "Rockwell Automation's Turbo-Encabulator", "Electronic Numarical Integrator and Computer", "Conway's Game of Life", "Bonsai", "Peregrine Falcon"]
    feedback("Mini_Assignment_1_Block_3")
    return True
  def code_block_4():
    print(my_list.index("Bonsai"))
    print(my_list.index(input("Enter a value to get it's positon (CASE SENSITIVE): ")))
    print("Hope you found what you were looking for.")
    feedback("Mini_Assignment_1_Block_4")
    return True
  def code_block_5():
    slices = my_list[slice(3,6)]
    print(slices)
    val_1 = eval(input("Enter a lower limit between 0 and 8:\t")) - 1
    val_2 = eval(input("Enter a upper limit between 0 and 8:\t")) - 1
    valid_1 = validate_Index(val_1)
    valid_2 = validate_Index(val_2)
    if valid_1 and valid_2 and (valid_1 < valid_2):
      slices = my_list[slice(val_1,val_2)]
      print(slices)
    else:
      return False
    feedback("Mini_Assignment_1_Block_5")
    return True
  def code_block_6():
    valid = upTo()
    print("Hope you found what you were looking for.")
    feedback("Mini_Assignment_1_Block_6")
    return True

# Mini Assignment 2
class mini_assignment_2:
  def code_block_1():
    return True

  def code_block_2():
    # 1 column (2 different ways)
    # 1 row (2 different ways)
    # 3 rows (2 different ways)
    # At least 1 row according to a conditional statement 
    feedback("Mini_Assignment_2_Block_1")
    return True

# Main Method
def main():
  valid = False
  program = 1
  while valid == False:
    try:
      print("1). Mini assignment 1")
      print("2). Mini assignment 2")
      print("3). Mini assignment 3")
      assignment_id = eval(input("Select the number of the assignment you want to run.\t"))
      if assignment_id == 1:
        print("1). Write a function that has 2 parameters: the 2 side lengths of a rectangle. Compute the area of the rectangle and return this value.")
        print("2). Show an example of invoking the above function.")
        print("3). Create a list of 8 things.")
        print("4). Index the above list to give one item in the list.")
        print("5). Slice the above list to get a sub-list.")
        print("6). Write a function that asks a user for a number less than 8. Use a for loop to print out the things in your list with index up to that number.")
        program = eval(input("Select the number of the code block you want to run.\t"))
        assignment = mini_assignment_2
        if program == 1:
          valid = assignment.code_block_1()
        elif program == 2:
          valid = assignment.code_block_2()
        elif program == 3:
          valid = assignment.code_block_3()
        elif program == 4:
          valid = assignment.code_block_4()
        elif program == 5:
          valid = assignment.code_block_5()
        elif program == 6:
          valid = assignment.code_block_6()
      elif assignment_id == 2:
        print("Pandas Data Series, Data Frames, and Indexing Mini Assignment:")
        print("1). Create 2 dictionaries with at least 5 key-value pairs with the same label (like our 5 states with a dictionary for population and area). Create Series with both of these dictionaries. Then, create a DataFrame with the 2 Series. (Make up whatever data you’d like for this–it could even be related to your project.)")
        print("2). Index this data frame to show: ")
        program = eval(input("Select the number of the code block you want to run.\t"))
        assignment = mini_assignment_1
        if program == 1:
          valid = assignment.code_block_1()
        elif program == 2:
          valid = assignment.code_block_2()
    except ValueError:
      if program == 4:
        print("Not in list") 
      else:
        print("Invalid value") 
    except IndexError:
      if program == 4:
        print("Not in list") 
      else:
        print("Index out of bounds.")
    except Exception as x:
      print("Something whent wrong.")
      print(x)
    except KeyboardInterrupt:
      print("Please don't leave without giving feedback.")
      break
    if input("Try Again [y]es / [n]o:\t") == "n":
      break
  print("Good Bye...")
  return

main()
# Out:
# True
# 1). Mini assignment 1
# 2). Mini assignment 2
# 3). Mini assignment 3

# %%
pd.DataFrame({
    "price" : [2, 3, 5], 
    "color" : ["yellow", "red", "blue"],
    "rating" : [4.2, 5.3, 6.2],
    "has support" : [False, True, True]
  },
  index = ["walmart", "amazon", "target"],
  )

pd.DataFrame(
    data=[
          [2, "yellow", 4.2, False],
          [3, "orange", 5.3, True],
          [5, "red", 6.2, True]
    ], columns = ["Price ($)", "Logo Color", "Customer Rating", "Has Phone Support"],
    index = ["walmart", "amazon", "target"],
    
)


#dtypes = [("int", int), ("str", str), ("float", float), ("bool", bool)]
# Out:
#          Price ($) Logo Color  Customer Rating  Has Phone Support
# walmart          2     yellow              4.2              False
# amazon           3     orange              5.3               True
# target           5        red              6.2               True
